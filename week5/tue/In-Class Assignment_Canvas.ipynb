# %% [markdown]
# ## **California Housing Prices**
# Build a Feed-Forward Neural Network that predicts the house value for different districts in California.
#
# **The Data:** We are using the California Housing Dataset. The target variable is the house price (measured in hundreds of thousands of dollars, e.g., 2.5 = $250,000). You have 8 numerical features to base your predictions on, including median income, house age, and number of rooms.
#
# **Your Tasks:**
# 1. Perform a strict 3-way data split (Train, Validation, Test).
# 2. Scale the data properly to prevent data leakage.
# 3. Build a PyTorch model with at least two hidden layers and ReLU activations.
# 4. Write the training and validation loop.
# 5. Plot your loss to check for overfitting!

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from torch.utils.data import TensorDataset, DataLoader

# Load the dataset automatically
housing = fetch_california_housing()
X = housing.data
y = housing.target

print(f"Dataset loaded! Total rows: {X.shape[0]} | Total features: {X.shape[1]}")
# Out:
# Dataset loaded! Total rows: 20640 | Total features: 8

# %% [markdown]
# ## **Data Splitting & Scaling**
#
# -  Split X and y into a temporary set (85%) and a Test set (15%)
# -  Split the temporary set into Train (82%) and Validation (18%)
# - Initialize the StandardScaler and scale your 3 datasets properly.

# %%
# Do NOT Run This
# Out:
# Train set size: 14386 | Validation set size: 3158 | Test set size: 3096

# %% [markdown]
# Scale data

# %% [markdown]
# ## **Tensors and DataLoaders**

# %%
# Convert to PyTorch Tensors





# Create DataLoaders

# %% [markdown]
# ## **Build the model**

# %%
# Do NOT Run This
# Out:
# CaliforniaHousingModel(
#   (layer1): Linear(in_features=8, out_features=128, bias=True)
#   (layer2): Linear(in_features=128, out_features=32, bias=True)
#   (layer3): Linear(in_features=32, out_features=8, bias=True)
#   (output_layer): Linear(in_features=8, out_features=1, bias=True)
#   (relu): ReLU()
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
# Define the Loss Function for Regression (MSE)


# Define the Optimizer (Adam) with a learning rate of 0.001

# %% [markdown]
# ## **The Training Loop**

# %%
# Do NOT Run This
# Out:
# Epoch [10/100] | Train Loss: 0.4733 | Val Loss: 0.3559
# Epoch [20/100] | Train Loss: 0.4144 | Val Loss: 0.3059
# Epoch [30/100] | Train Loss: 0.3963 | Val Loss: 0.3096
# Epoch [40/100] | Train Loss: 0.3827 | Val Loss: 0.2867
# Epoch [50/100] | Train Loss: 0.3766 | Val Loss: 0.2811
# Epoch [60/100] | Train Loss: 0.3782 | Val Loss: 0.2692
# Epoch [70/100] | Train Loss: 0.3762 | Val Loss: 0.2886
# Epoch [80/100] | Train Loss: 0.3761 | Val Loss: 0.2877
# Epoch [90/100] | Train Loss: 0.3697 | Val Loss: 0.2687
# Epoch [100/100] | Train Loss: 0.3667 | Val Loss: 0.2767

# %% [markdown]
# ## **Plot The Loss Curve**
#
# - Use matplotlib to plot train_losses and val_losses

# %%
# Do NOT Run This

# %% [markdown]
# ## **Final Testset Evaluation**

# %%
# Do NOT Run This
# Out:
# Final Test Loss (MSE): 0.2742
# Final Test RMSE: $52,363.24
# Final R2 Score: 0.7914 (79.1%)
