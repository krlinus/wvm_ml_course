# %% [markdown]
# # **Part 3: Combining DataFrames, Text & Date Methods in Pandas**
#
# ### **Dataset Introduction**
#
# In this project, we will work with the Palmer Penguins dataset, which contains measurements of penguins observed on islands near Antarctica.
#
# Please download the dataset [penguins.csv](https://drive.google.com/file/d/1dv8A8v_sdf29p1At40S7KBslJPmBA3e9/view?usp=sharing) or from canvas.
#
# ### **Dataset Description**
#
# Each row represents a penguin, and columns include:
#
# - species – Penguin species
# - island – Island where the penguin was found
# - bill_length_mm – Bill length (mm)
# - bill_depth_mm – Bill depth (mm)
# - flipper_length_mm – Flipper length (mm)
# - body_mass_g – Body mass (grams)
# - sex – Sex of the penguin
#
# Some values are missing, which makes this dataset ideal for practicing missing data handling.

# %% [markdown]
# ### **Load the Dataset**

# %%
import pandas as pd
df=pd.read_csv('penguins.csv')

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %% [markdown]
# ### **Part 1 — Basic Pandas Commands**

# %% [markdown]
# Q1. Display the dataset information.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
# DO NOT RUN THIS
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# Q2. Display the number of unique species and unique islands.

# %%
df['species'].nunique()
# Out:
# 3

# %%
df['island'].nunique()
# Out:
# 3

# %%
# DO NOT RUN THIS
# Out:
# 3

# %%
# DO NOT RUN THIS
# Out:
# 3

# %% [markdown]
# ### **Part 2 — GroupBy Basics**

# %% [markdown]
# Q3. Compute the average body mass for each species.

# %%
#df.groupby('species').body_mass_g.mean().to_frame()

#df[['species','body_mass_g']].groupby('species').mean()
#df.groupby('species', as_index=False)['body_mass_g'].mean()
#type(df[['species','body_mass_g']].groupby('species').mean())
#type(df.groupby('species')['body_mass_g'].mean())
df.groupby('species')['body_mass_g'].mean().to_frame()
# Out:
#            body_mass_g
# species
# Adelie     3700.662252
# Chinstrap  3733.088235
# Gentoo     5076.016260

# %%
# DO NOT RUN THIS
# Out:
# species
# Adelie       3700.662252
# Chinstrap    3733.088235
# Gentoo       5076.016260
# Name: body_mass_g, dtype: float64

# %% [markdown]
# Q4. Compute the average flipper length for each island.

# %%
df.groupby('island')['flipper_length_mm'].mean().to_frame()
# Out:
#            flipper_length_mm
# island
# Biscoe            209.706587
# Dream             193.072581
# Torgersen         191.196078

# %%
# DO NOT RUN THIS
# Out:
# island
# Biscoe       209.706587
# Dream        193.072581
# Torgersen    191.196078
# Name: flipper_length_mm, dtype: float64

# %% [markdown]
# Q5. For each species, find the minimum, maximum, and mean of bill_length_mm.

# %%
df.groupby('species')['bill_length_mm'].agg(['min','max','mean'])
# Out:
#             min   max       mean
# species
# Adelie     32.1  46.0  38.791391
# Chinstrap  40.9  58.0  48.833824
# Gentoo     40.9  59.6  47.504878

# %%
# DO NOT RUN THIS
# Out:
#             min   max       mean
# species
# Adelie     32.1  46.0  38.791391
# Chinstrap  40.9  58.0  48.833824
# Gentoo     40.9  59.6  47.504878

# %% [markdown]
# Q6. For each species–island combination, find the number of non-missing body mass measurements.

# %%
df.groupby(['species','island'])['body_mass_g'].size().to_frame()
# Out:
#                      body_mass_g
# species   island
# Adelie    Biscoe              44
#           Dream               56
#           Torgersen           52
# Chinstrap Dream               68
# Gentoo    Biscoe             124

# %%
# DO NOT RUN THIS
# Out:
# species    island
# Adelie     Biscoe        44
#            Dream         56
#            Torgersen     51
# Chinstrap  Dream         68
# Gentoo     Biscoe       123
# Name: body_mass_g, dtype: int64

# %% [markdown]
# Q7. Identify the species with the largest average body mass.

# %%
df.groupby('species')['body_mass_g'].mean().idxmax()
# Out:
# 'Gentoo'

# %%
# DO NOT RUN THIS
# Out:
# 'Gentoo'

# %% [markdown]
# Q8. Sort islands by descending average flipper length.

# %%
df.groupby('island')['flipper_length_mm'].mean().sort_values(ascending=False).to_frame()
# Out:
#            flipper_length_mm
# island
# Biscoe            209.706587
# Dream             193.072581
# Torgersen         191.196078

# %%
# DO NOT RUN THIS
# Out:
# island
# Biscoe       209.706587
# Dream        193.072581
# Torgersen    191.196078
# Name: flipper_length_mm, dtype: float64

# %% [markdown]
# Q9.Find species–island groups with at least 20 penguins.

# %%
df.groupby(['species','island']).filter(lambda x: len(x) >= 20)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
# DO NOT RUN THIS
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %% [markdown]
# Q10. For each species, compute:
#
# - average body mass
# - average flipper length

# %%
df.groupby('species')[['body_mass_g','flipper_length_mm']].mean()
# Out:
#            body_mass_g  flipper_length_mm
# species
# Adelie     3700.662252         189.953642
# Chinstrap  3733.088235         195.823529
# Gentoo     5076.016260         217.186992

# %%
# DO NOT RUN THIS
# Out:
#            body_mass_g  flipper_length_mm
# species
# Adelie     3700.662252         189.953642
# Chinstrap  3733.088235         195.823529
# Gentoo     5076.016260         217.186992

# %% [markdown]
# Q11. For each island, compute:
#
# - count of penguins
# - mean body mass
# - standard deviation of body mass

# %%
#df.groupby('species')['bill_length_mm'].agg(['min','max','mean'])
df.groupby('island')['body_mass_g'].agg(['count','mean','std'])
# Out:
#            count         mean         std
# island
# Biscoe       167  4716.017964  782.855743
# Dream        124  3712.903226  416.644112
# Torgersen     51  3706.372549  445.107940

# %%
# DO NOT RUN THIS
# Out:
#            count         mean         std
# island
# Biscoe       167  4716.017964  782.855743
# Dream        124  3712.903226  416.644112
# Torgersen     51  3706.372549  445.107940

# %% [markdown]
# ### **Part 3 — Combining DataFrames + GroupBy**

# %% [markdown]
# Q12. Create the following penguin_regions dataframe and merge with penguins.
#
#
#
# ```
# {
#     'island': ['Biscoe', 'Dream', 'Torgersen'],
#     'region': ['Antarctica', 'Antarctica', 'Antarctica']
# }
# ```

# %%
new_data=pd.DataFrame({
    'island': ['Biscoe', 'Dream', 'Torgersen'],
    'region': ['Antarctica', 'Antarctica', 'Antarctica']
})
df2=df.merge(new_data)
#df2
# Out:
#      region  island
# 0     False   False
# 1     False   False
# 2     False   False
# 3     False   False
# 4     False   False
# ..      ...     ...
# 339   False   False
# 340   False   False
# 341   False   False
# 342   False   False
# 343   False   False
#
# [344 rows x 2 columns]

# %%
df2[df2[['region','island']].notna()]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       NaN  Torgersen             NaN            NaN                NaN
# 1       NaN  Torgersen             NaN            NaN                NaN
# 2       NaN  Torgersen             NaN            NaN                NaN
# 3       NaN  Torgersen             NaN            NaN                NaN
# 4       NaN  Torgersen             NaN            NaN                NaN
# ..      ...        ...             ...            ...                ...
# 339     NaN     Biscoe             NaN            NaN                NaN
# 340     NaN     Biscoe             NaN            NaN                NaN
# 341     NaN     Biscoe             NaN            NaN                NaN
# 342     NaN     Biscoe             NaN            NaN                NaN
# 343     NaN     Biscoe             NaN            NaN                NaN
#
#      body_mass_g  sex      region
# 0            NaN  NaN  Antarctica
# ...

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %% [markdown]
# Q13. Compute the average body mass per region.

# %%
df2.groupby('region')['body_mass_g'].mean().to_frame()
# Out:
#             body_mass_g
# region
# Antarctica  4201.754386

# %%
# DO NOT RUN THIS
# Out:
# region
# Antarctica    4201.754386
# Name: body_mass_g, dtype: float64

# %% [markdown]
# Q14.Compute the average body_mass_g grouped by species, and then compute the overall average body_mass_g without grouping.
#
# - Why are the species-level averages different from the overall average?
# - What does this tell you about how groupby() changes the interpretation of results?

# %%
df['body_mass_g'].mean()
# Out:
# np.float64(4201.754385964912)

# %%
# DO NOT RUN THIS
# Out:
# np.float64(4201.754385964912)

# %%
df.groupby('species')['body_mass_g'].mean().to_frame()
# Out:
#            body_mass_g
# species
# Adelie     3700.662252
# Chinstrap  3733.088235
# Gentoo     5076.016260

# %%
# DO NOT RUN THIS
# Out:
# species
# Adelie       3700.662252
# Chinstrap    3733.088235
# Gentoo       5076.016260
# Name: body_mass_g, dtype: float64

# %% [markdown]
# Your Explanation:

# %% [markdown]
# GroupBy produces a more nuanced value by drilling down. Here the difference in sizes of the species of penguins
# is made apparent

# %% [markdown]
# ### **Part 4 — GroupBy with Text Methods**

# %% [markdown]
# Q15. Create species_lower with lowercase species names.

# %%
df['species_lower']=df['species'].str.lower()
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex species_lower
# 0       3750.0    MALE        adelie
# 1       3800.0  FEMALE        adelie
# 2       3250.0  FEMALE        adelie
# 3          NaN     NaN        adelie
# 4       3450.0  FEMALE        adelie

# %%
# DO NOT RUN THIS
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex species_lower
# 0       3750.0    MALE        adelie
# 1       3800.0  FEMALE        adelie
# 2       3250.0  FEMALE        adelie
# 3          NaN     NaN        adelie
# 4       3450.0  FEMALE        adelie

# %% [markdown]
# Q16. After creating the species_lower column, you want to verify that converting text to lowercase did not change the number of observations for each species.
#
# Compute the number of penguins for each value in species_lower.

# %%
df.groupby('species_lower')['species_lower'].value_counts().to_frame()
# Out:
#                count
# species_lower
# adelie           152
# chinstrap         68
# gentoo           124

# %%
# DO NOT RUN THIS
# Out:
# species_lower
# adelie       152
# gentoo       124
# chinstrap     68
# Name: count, dtype: int64

# %% [markdown]
# Q17. Create penguin_observations, with the following data.
#
# observation_date': '2019-01-15', '2019-02-20', '2020-01-05', '2020-03-18'

# %%
penguin_observations=pd.DataFrame({'penguin_id':[1,2,3,4],'observation_date': ['2019-01-15', '2019-02-20', '2020-01-05', '2020-03-18']})
penguin_observations
# Out:
#    penguin_id observation_date
# 0           1       2019-01-15
# 1           2       2019-02-20
# 2           3       2020-01-05
# 3           4       2020-03-18

# %%
# DO NOT RUN THIS
# Out:
#    penguin_id observation_date
# 0           1       2019-01-15
# 1           2       2019-02-20
# 2           3       2020-01-05
# 3           4       2020-03-18

# %% [markdown]
# Q19. Convert observation_date to datetime and extract year.

# %%
po=pd.to_datetime(penguin_observations['observation_date']).dt.year
po
# Out:
# 0    2019
# 1    2019
# 2    2020
# 3    2020
# Name: observation_date, dtype: int32

# %%
porec=pd.DataFrame(po)
penguin_observations['year']=porec
penguin_observations
# Out:
#    penguin_id observation_date  year
# 0           1       2019-01-15  2019
# 1           2       2019-02-20  2019
# 2           3       2020-01-05  2020
# 3           4       2020-03-18  2020

# %%
# DO NOT RUN THIS
# Out:
#    penguin_id observation_date  year
# 0           1       2019-01-15  2019
# 1           2       2019-02-20  2019
# 2           3       2020-01-05  2020
# 3           4       2020-03-18  2020

# %% [markdown]
# Q20. Merge with original penguins dataframe and show the head.

# %%
# DO NOT RUN THIS
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex species_lower  penguin_id observation_date    year
# 0       3750.0    MALE        adelie           0       2019-01-15  2019.0
# 1       3800.0  FEMALE        adelie           1       2019-02-20  2019.0
# 2       3250.0  FEMALE        adelie           2       2020-01-05  2020.0
# 3          NaN     NaN        adelie           3       2020-03-18  2020.0
# 4       3450.0  FEMALE        adelie           4              NaT     NaN

# %%
penguin_observations
# Out:
#    penguin_id observation_date  year
# 0           1       2019-01-15  2019
# 1           2       2019-02-20  2019
# 2           3       2020-01-05  2020
# 3           4       2020-03-18  2020

# %%
df1=df.merge(penguin_observations,left_index=True,right_on='penguin_id')
df1
# The requirement wasn't clear enough, so making the best sense as it seems to me
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.5           17.4              186.0
# 1  Adelie  Torgersen            40.3           18.0              195.0
# 2  Adelie  Torgersen             NaN            NaN                NaN
# 3  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex species_lower  penguin_id observation_date  year
# 0       3800.0  FEMALE        adelie           1       2019-01-15  2019
# 1       3250.0  FEMALE        adelie           2       2019-02-20  2019
# 2          NaN     NaN        adelie           3       2020-01-05  2020
# 3       3450.0  FEMALE        adelie           4       2020-03-18  2020
