# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

fig,mp=plt.subplots(1,1)
x_data=np.arange(0,25,2)
y_data=np.random.randn(len(x_data))

mp.plot(x_data,y_data)

# %%
fig,mp=plt.subplots(1,1)
mp.scatter(x_data,y_data+30)
mp.bar(x_data,y_data)
# Out:
# <BarContainer object of 13 artists>
