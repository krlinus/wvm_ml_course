# %% [markdown]
# # **Linear Regression with PyTorch Assignment**

# %% [markdown]
#  ### **Import libraries**

# %% [markdown]
# ### **Data**

# %%
torch.manual_seed(71) # to obtain reproducible results
X = torch.linspace(-3, 3, 100).reshape(-1,1)
noise = 0.08 * torch.randn(100,1)
y = torch.tanh(X - 1) * 0.9 + 0.1 + noise

# %% [markdown]
# ### **Plot the results**

# %%
# Do Not Run this

# %% [markdown]
# ### **Model classes**
# Define the models class. For now, though, we only need a single <tt>linear</tt> layer.

# %% [markdown]
# When <tt>Model</tt> is instantiated, we need to pass in the size (dimensions) of the incoming and outgoing features. For our purposes we'll use (1,1).

# %%
# Do Not Run this
# Out:
# Model(
#   (linear): Linear(in_features=1, out_features=1, bias=True)
# )

# %% [markdown]
# ### **Set the loss function**

# %% [markdown]
# ### **Set the optimization**

# %% [markdown]
# ### **Train the model**

# %%
# Do Not Run this
# Out:
# epoch:  1  loss: 1.63629925  weight: 0.10597813  bias: 0.96379614
# epoch:  2  loss: 1.55816960  weight: 0.12179427  bias: 0.94046706
# epoch:  3  loss: 1.48505127  weight: 0.13664226  bias: 0.91760457
# epoch:  4  loss: 1.41651845  weight: 0.15058137  bias: 0.89519930
# epoch:  5  loss: 1.35218883  weight: 0.16366725  bias: 0.87324214
# epoch:  6  loss: 1.29171968  weight: 0.17595212  bias: 0.85172415
# epoch:  7  loss: 1.23480189  weight: 0.18748499  bias: 0.83063650
# epoch:  8  loss: 1.18115759  weight: 0.19831192  bias: 0.80997062
# epoch:  9  loss: 1.13053608  weight: 0.20847611  bias: 0.78971803
# epoch: 10  loss: 1.08271122  weight: 0.21801811  bias: 0.76987052
# epoch: 11  loss: 1.03747833  weight: 0.22697605  bias: 0.75041997
# epoch: 12  loss: 0.99465173  weight: 0.23538564  bias: 0.73135841
# epoch: 13  loss: 0.95406306  weight: 0.24328047  bias: 0.71267807
# epoch: 14  loss: 0.91555971  weight: 0.25069204  bias: 0.69437134
# ...

# %% [markdown]
# ### **Plot the loss values**
# Let's see how loss changed over time

# %%
# Do Not Run this

# %% [markdown]
# ### **Plot the result**

# %%
# Do Not Run this

# %% [markdown]
# ## **Add Activation Function**
#
# Let's go beyond the linear regression and add an activation function to our model and repeat the process.

# %%
class Model(nn.Module):
    def __init__(self, in_features, out_features):
        super().__init__()
        self.linear = nn.Linear(in_features, out_features)
        self.act = nn.Tanh()

    def forward(self, x):
        y_pred = self.linear(x)
        y_pred = self.act(y_pred)
        return y_pred

# %%
# Do Not Run this
# Out:
# Model(
#   (linear): Linear(in_features=1, out_features=1, bias=True)
#   (act): Tanh()
# )

# %%
# Do Not Run this
# Out:
# epoch:  1  loss: 1.26152754  weight: 0.10597813  bias: 0.96379614
# epoch:  2  loss: 1.23716474  weight: 0.11800084  bias: 0.95399719
# epoch:  3  loss: 1.21157992  weight: 0.13035394  bias: 0.94398504
# epoch:  4  loss: 1.18480766  weight: 0.14302014  bias: 0.93376684
# epoch:  5  loss: 1.15691268  weight: 0.15597503  bias: 0.92335296
# epoch:  6  loss: 1.12799346  weight: 0.16918662  bias: 0.91275716
# epoch:  7  loss: 1.09818327  weight: 0.18261507  bias: 0.90199679
# epoch:  8  loss: 1.06765103  weight: 0.19621290  bias: 0.89109278
# epoch:  9  loss: 1.03659642  weight: 0.20992576  bias: 0.88006926
# epoch: 10  loss: 1.00524449  weight: 0.22369362  bias: 0.86895311
# epoch: 11  loss: 0.97383708  weight: 0.23745266  bias: 0.85777342
# epoch: 12  loss: 0.94262010  weight: 0.25113735  bias: 0.84656042
# epoch: 13  loss: 0.91183299  weight: 0.26468295  bias: 0.83534443
# epoch: 14  loss: 0.88169700  weight: 0.27802786  bias: 0.82415503
# ...

# %%
# Do Not Run this

# %%
# Do Not Run this
