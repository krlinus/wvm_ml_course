# %% [markdown]
# # **California Housing Dataset Regression Project**

# %% [markdown]
# This project focuses on various regression techniques using the **California Housing Dataset**. It is a widely used benchmark dataset for regression tasks. It contains aggregated census data for various districts in California.
#
# **Key characteristics:**
#
# *   **Target Variable:** Median house value for California districts.
# *   **Features:** Includes attributes like median income, housing age, average number of rooms, population, occupancy, latitude, and longitude.
# *   **Goal:** The primary goal is to predict the median house value based on the given features. It's an excellent dataset for demonstrating linear regression concepts due to its diverse set of numerical features and the clear regression objective.

# %% [markdown]
# ## **Part 1 – Data Loading and Understanding**

# %% [markdown]
# Load the California Housing dataset (`housing.csv`) into a pandas DataFrame.
# Display
#
#
# *   shape of the dataset
# *   column names

# %%
# Do NOT Run This Cell
# Out:
# Dataset Shape: (20640, 10)
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %% [markdown]
# Since categorical encoding has not been covered in class so far, remove the categorical column/columns from the dataset before building regression models.
#
# Also, remove rows with missing values.
#
# Display the new dataset shape.

# %%
# Do NOT Run This Cell
# Out:
# (20433, 9)

# %% [markdown]
# <br>

# %% [markdown]
# ## **Part 2 – Data Preparation**
#
# Separate the features (X) and target (y).

# %% [markdown]
# Split the dataset into training and testing sets. Use 80% of the data for training and 20% for testing. Set `random_state` to 42 for reproducibility.
#
# Display the shapes.

# %%
# Do NOT Run This Cell
# Out:
# (16346, 8)
# (4087, 8)

# %% [markdown]
# <br><br>

# %% [markdown]
# ## **Part 3 – Model Training and Evaluation**

# %% [markdown]
# Train a linear regression model using SGDRegressor.
#
# Use the following parameters:
#
# - max_iter=1000
# - tol=1e-3
# - random_state=42

# %%
# Do NOT Run This Cell
# Out:
# SGDRegressor(random_state=42)

# %% [markdown]
# Predict the house prices for the test set and compute MAE, MSE, RMSE, R²

# %%
# Do NOT Run This Cell
# Out:
# MAE : 989305014444733.9
# MSE : 1.7725808260038138e+30
# RMSE: 1331383050066288.8
# R² : -1.2962028464093038e+20

# %% [markdown]
# Compare the results of
#
#  - Multiple Linear Regression
#  - Gradient Descent Linear Regression
#
# #### **Questions**
# - Which model performs better?
# - Why might the performance differ?
# - Do you notice any issue with the result of `SGDRegressor`?

# %% [markdown]
# <br><br>

# %% [markdown]
# ## **Part 4 – Feature Scaling**

# %% [markdown]
# Standardize data using StandardScaler.
#
# Display the mean and standard deviation of the scaled training data.

# %%
# Do NOT Run This Cell
# Out:
# longitude            -5.914379e-15
# latitude              4.338197e-16
# housing_median_age    1.477943e-17
# total_rooms          -1.034560e-16
# total_bedrooms       -4.086077e-17
# population           -4.346891e-18
# households            3.564450e-17
# median_income        -6.868087e-17
# dtype: float64
# longitude             1.000031
# latitude              1.000031
# housing_median_age    1.000031
# total_rooms           1.000031
# total_bedrooms        1.000031
# population            1.000031
# households            1.000031
# median_income         1.000031
# dtype: float64

# %% [markdown]
# #### **Question**
#
# Should feature scaling be performed before train-test split or after train-test split using only the training data
#
# Explain your answer.

# %% [markdown]
# <br>

# %% [markdown]
# Train your previous `SGDRegressor` model this time using the scaled data.
#
# Compute MAE, MSE, RMSE and R² and compare with the unscaled model.

# %%
# Do NOT Run This Cell
# Out:
# SGDRegressor(random_state=42)

# %%
# Do NOT Run This Cell
# Out:
# MAE : 51649.47812651031
# MSE : 4932018147.226794
# RMSE: 70228.32866605038
# R² : 0.6393453056022194

# %% [markdown]
# #### **Questions**
#
# - How are the results compare with the unscaled version?
# - Why is feature scaling especially important for gradient descent?
# - Does LinearRegression suffer from the same problem?

# %% [markdown]
# <br><br>

# %% [markdown]
# ## **Part 5 – Cross Validation**

# %% [markdown]
# Use 5-fold cross-validation to evaluate a Multiple Linear Regression model.
#
# Compute and report MSE & RMSE for each fold, as well as the mean and std of RMSEs

# %%
# Do NOT Run This Cell
# Out:
# Cross-validation scores (Mean Squared Error):
#  [4.41986867e+09 5.57981183e+09 5.99422106e+09 5.33009464e+09
#  4.47253150e+09]
#
# Cross-validation scores (Root Mean Squared Error):
#  [66482.09284369 74698.13807402 77422.35503368 73007.4971405
#  66876.98783073]
#
# Mean RMSE: 71697.4142
# Standard deviation of RMSE scores: 4334.3211

# %% [markdown]
# #### **Question**
#
# Explain why cross-validation provides a better estimate of model performance than a single train-test split.

# %% [markdown]
# <br><br>

# %% [markdown]
# ## **Part 6 – Bias-Variance Tradeoff**

# %% [markdown]
# Train Polynomial Regression models with Degree 1,2,3,4.
#
# Record Training R², Testing R², Training MAE, Testing MAE.

# %%
# Do NOT Run This Cell
# Out:
#    Degree  Training R²  Testing R²  Training MAE   Testing MAE
# 0       1     0.636019    0.640087  50629.497419  51372.672171
# 1       2     0.698996    0.698250  44961.140720  46019.770362
# 2       3     0.737269    0.710568  42030.188526  44121.399172
# 3       5     0.594624  -16.427414  54224.392944  71603.720031

# %% [markdown]
# #### **Questions**
#
# - Which degree has the highest training R²?
# - Which degree has the best testing R²?
# - Which degree appears to overfit?
# - Overall which degree do you choose?
