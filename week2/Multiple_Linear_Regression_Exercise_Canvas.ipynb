# %% [markdown]
# # **California Housing Dataset Regression Project**

# %% [markdown]
# This project focuses on various regression techniques using the **California Housing Dataset**. It is a widely used benchmark dataset for regression tasks. It contains aggregated census data for various districts in California.
#
# **Key characteristics:**
#
# *   **Target Variable:** Median house value for California districts.
# *   **Features:** Includes attributes like median income, housing age, average number of rooms, population, occupancy, latitude, and longitude.
# *   **Goal:** The primary goal is to predict the median house value based on the given features. It's an excellent dataset for demonstrating linear regression concepts due to its diverse set of numerical features and the clear regression objective.

# %% [markdown]
# ## **Part 1 – Data Loading and Understanding**

# %% [markdown]
# #### **Question 1**
#
# Load the California Housing dataset (`housing.csv`) into a pandas DataFrame.
# Display
#
#
# *   shape of the dataset
# *   column names
# *   first five rows

# %%
# Do NOT Run This Cell
# Out:
# Dataset Shape: (20640, 10)
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
# Do NOT Run This Cell
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# #### **Question 2**
#
# Display
#
# * data types
# * number of missing values
#
# Based on the results:
#
# * Which column contains missing values?
# * Which column is categorical?
# * Which column is the target variable?

# %%
# Do NOT Run This Cell
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
# Do NOT Run This Cell
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %% [markdown]
# #### **Question 3**
#
# Since categorical encoding has not been covered in class so far, remove the categorical column/columns from the dataset before building regression models.
#
# Also, remove rows with missing values.
#
# Display the new dataset shape.

# %%
# Do NOT Run This Cell
# Out:
# (20433, 9)

# %% [markdown]
# <br>

# %% [markdown]
# ## **Part 2 – Exploratory Data Analysis**

# %% [markdown]
# #### **Question 4 – Summary Statistics**
#
# Display the summary statistics for all numerical columns.
#
# Based on the summary statistics, answer the following:
#
# * Which feature has the largest average value?
# * Which feature has the largest standard deviation?
# * Which feature has the smallest minimum value?
# * Which feature appears to have the widest range?

# %%
# Do NOT Run This Cell
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20433.000000  20433.000000        20433.000000  20433.000000
# mean    -119.570689     35.633221           28.633094   2636.504233
# std        2.003578      2.136348           12.591805   2185.269567
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1450.000000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.720000           37.000000   3143.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20433.000000  20433.000000   20433.000000
# mean       537.870553   1424.946949    499.433465       3.871162
# std        421.385070   1133.208490    382.299226       1.899291
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# #### **Question 5**
# Create histograms for all numerical features and answer the following questions.
#
# - Which feature appears closest to a normal distribution?
# - Which feature is the most right-skewed?
# - Which feature has a limited range of values?

# %%
# Do NOT Run This Cell

# %% [markdown]
# #### **Question 6**
#
# Compute the correlation matrix and answer the following questions.
#
# - Which feature has the strongest positive correlation with house price?
# - Which feature has the strongest negative correlation with house price?
# - Which two predictor variables are most strongly correlated with each other?

# %%
# Do NOT Run This Cell
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924616           -0.109357     0.045480
# latitude            -0.924616  1.000000            0.011899    -0.036667
# housing_median_age  -0.109357  0.011899            1.000000    -0.360628
# total_rooms          0.045480 -0.036667           -0.360628     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.100270 -0.108997           -0.295787     0.857281
# households           0.056513 -0.071774           -0.302768     0.918992
# median_income       -0.015550 -0.079626           -0.118278     0.197882
# median_house_value  -0.045398 -0.144638            0.106432     0.133294
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.100270    0.056513      -0.015550
# latitude                 -0.066983   -0.108997   -0.071774      -0.079626
# ...

# %% [markdown]
# #### **Question 7**
#
# Create a heatmap of the correlation matrix.

# %%
# Do NOT Run This Cell
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# Here is the code for the same plot using `seaborn` library

# %%
import seaborn as sns

plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# #### **Question 8**
#
# Create a scatter plot of `median_income` and `median_house_value` and answer the following questions.
#
# - Describe the relationship.
# - Is it positive or negative?
# - Is the relationship strong or weak?
# - Do you observe any unusual patterns?

# %%
# Do NOT Run This Cell
# Out:
# Text(0.5, 1.0, 'Median Income vs House Value')

# %% [markdown]
# #### **Question 9**
#
# Create boxplots for all numerical columns and answer the following questions.
#
# - Which variables contain many outliers?
# - Which variable appears to have the largest spread?
# - Should we immediately remove all outliers? Explain.

# %%
# Do NOT Run This Cell
# Out:
# <Axes: >

# %% [markdown]
# #### **Question 10**
#
# Create a scatter plot for Latitude vs House Value and answer the following questions.
#
#
# - Does latitude alone explain house prices well?
# - Is the relationship linear?

# %%
# Do NOT Run This Cell
# Out:
# Text(0, 0.5, 'Median House Value')

# %% [markdown]
# #### **Question 11**
#
# Which three variables would you choose as predictors if you were building a regression model? Justify your choices based on the visualizations.

# %% [markdown]
# <br><br>

# %% [markdown]
# ## **Part 3 – Data Preparation**
#
# ####**Question 12**
#
# Separate the features (X) and target (y).

# %% [markdown]
# #### **Question 13**
#
# Split the dataset into training and testing sets. Use 80% of the data for training and 20% for testing. Set `random_state` to 42 for reproducibility.
#
# Display the shapes.

# %%
# Do NOT Run This Cell
# Out:
# (16346, 8)
# (4087, 8)

# %% [markdown]
# ## **Part 4 – Model Training and Evaluation**
#
# #### **Question 14**
#
# Train a Multiple Linear Regression model.
#
# Display the model's coefficients and intercept.

# %%
# Do NOT Run This Cell
# Out:
# Model Intercept: -3569674.5266952454
# Model Coefficients: [-4.25467060e+04 -4.23360430e+04  1.15509711e+03 -8.44041848e+00
#   1.15830375e+02 -3.67587673e+01  4.16404344e+01  4.02932784e+04]

# %% [markdown]
# #### **Question 15**
#
# Make predictions on the test set (`X_test`).

# %% [markdown]
# #### **Question 16**
#
# Calculate and display the Mean Squared Error (MSE), Mean Absolute Error (MAE) RMSE and R-squared (R2) score.
#
# Describe what these metrics tell you about the model's performance.

# %%
# Do NOT Run This Cell
# Out:
# Mean Squared Error (MSE): 4921881237.63
# Mean Absolute Error (MAE): 51372.67
# Root Mean Squared Error (RMSE): 70156.12
# R-squared (R2) Score: 0.64

# %% [markdown]
# #### **Question 17**
#
# Display the regression coefficients.
#
# Which feature has the largest positive coefficient?

# %%
# Do NOT Run This Cell
# Out:
# longitude            -42546.706006
# latitude             -42336.042987
# population              -36.758767
# total_rooms              -8.440418
# households               41.640434
# total_bedrooms          115.830375
# housing_median_age     1155.097108
# median_income         40293.278408
# dtype: float64

# %% [markdown]
# <br><br>

# %% [markdown]
# ## **Part 5 – Polynomial Regression**

# %% [markdown]
# Instead of creating polynomial features from all eight variables (which would produce a very large feature set and make interpretation difficult), focus on one predictor that has the strongest relationship with the target.

# %% [markdown]
# #### **Question 18**
#
# Using only the `median_income` feature, create a Polynomial Regression model with degree 2.
#
# Steps:
#
# - Extract the MedInc feature.
# - Split into training and testing sets.
# - Generate polynomial features (degree = 2).
# - Train a Linear Regression model on the transformed data.
# - Predict on the test set.

# %%
# Do NOT Run This Cell
# Out:
# (16346, 45)

# %% [markdown]
# #### **Question 19**
#
# Evaluate the Polynomial Regression model by calculating the Mean Squared Error (MSE), Mean Absolute Error (MAE), Root Mean Squared Error (RMSE), and R-squared (R2) score.
#
# Compare these metrics to the Multiple Linear Regression model's metrics and discuss whether polynomial features improved the model's performance.

# %%
# Do NOT Run This Cell
# Out:
# Polynomial Regression MSE: 4126489685.40
# Polynomial Regression MAE: 46019.77
# Polynomial Regression RMSE: 64237.76
# Polynomial Regression R2 Score: 0.70

# %% [markdown]
# #### **Question 20**
#
# Answer the following questions in complete sentences:
#
# - Which evaluation metric do you think is the easiest to interpret, and why?
