# %% [markdown]
# # **California Housing Dataset Regression Project**

# %% [markdown]
# This project focuses on various regression techniques using the **California Housing Dataset**. It is a widely used benchmark dataset for regression tasks. It contains aggregated census data for various districts in California.
#
# **Key characteristics:**
#
# *   **Target Variable:** Median house value for California districts.
# *   **Features:** Includes attributes like median income, housing age, average number of rooms, population, occupancy, latitude, and longitude.
# *   **Goal:** The primary goal is to predict the median house value based on the given features. It's an excellent dataset for demonstrating linear regression concepts due to its diverse set of numerical features and the clear regression objective.

# %% [markdown]
# ## **Part 1 – Data Loading and Understanding**

# %% [markdown]
# Load the California Housing dataset (`housing.csv`) into a pandas DataFrame.
# Display
#
#
# *   shape of the dataset
# *   column names

# %%
# Do NOT Run This Cell
# Out:
# Dataset Shape: (20640, 10)
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %% [markdown]
# Since categorical encoding has not been covered in class so far, remove the categorical column/columns from the dataset before building regression models.
#
# Also, remove rows with missing values.
#
# Display the new dataset shape.

# %%
# Do NOT Run This Cell
# Out:
# (20433, 9)

# %% [markdown]
# <br>

# %% [markdown]
# ## **Part 2 – Data Preparation**
#
# Separate the features (X) and target (y).

# %% [markdown]
# Split the dataset into training and testing sets. Use 80% of the data for training and 20% for testing. Set `random_state` to 42 for reproducibility.
#
# Display the shapes.

# %%
# Do NOT Run This Cell
# Out:
# (16346, 8)
# (4087, 8)

# %% [markdown]
# Scale the data:

# %% [markdown]
# **Questions**
# - Why is scaling important for regularized models?
# - What problem may occur if features are not scaled?

# %% [markdown]
# <br><br>

# %% [markdown]
# ## **Part 3 – Regularization**

# %% [markdown]
# Create a Ridge model with `alpha = 100` , Train the model, Predict on the test set, Calculate the MAE, MSE, RMSE and R2

# %%
# Do NOT Run This Cell
# Out:
# Ridge(alpha=100)

# %% [markdown]
# Predict the house prices for the test set and compute MAE, MSE, RMSE, R²

# %%
# Do NOT Run This Cell
# Out:
# MAE : 51449.86069467655
# MSE : 4938995890.987808
# RMSE: 70277.99008927196
# R² : 0.6388350568625367

# %% [markdown]
# <br><br>

# %% [markdown]
# ## **Part 4 – CV Regularization**

# %% [markdown]
# Use `RidgeCV, with candidate values: `alphas = [0.01,0.1,1,10,100]` and `neg_mean_absolute_error`.
# - Find the best alpha automatically.
# - Evaluate on the test set.

# %%
# Do NOT Run This Cell
# Out:
# Best Alpha: 10.0

# %%
# Do NOT Run This Cell
# Out:
# MAE : 51374.283754802505
# MSE : 4922780552.735694
# RMSE: 70162.52954915247
# R² : 0.6400208063239738

# %% [markdown]
# <br>

# %% [markdown]
# Do the same for `LASSO` and `Elastic Net`

# %% [markdown]
# <br><br>

# %% [markdown]
# ## **Part 5 – Grid Search**

# %% [markdown]
# Perform Grid Search for Elastic Net with the following parameters:
#
#
#
# ```
# alpha:[0.01,0.1,1,10,100],
# l1_ratio:[0.1,0.3,0.5,0.7,0.9,1]
#
# cv=5
# scoring='neg_mean_squared_error'
# ```
# Report: best_params and best_estimator
#
# Then evaluate best model on test set & report the metrics.

# %%
# Do NOT Run This Cell
# Out:
# GridSearchCV(cv=5, estimator=ElasticNet(),
#              param_grid={'alpha': [0.01, 0.1, 1, 10, 100],
#                          'l1_ratio': [0.1, 0.3, 0.5, 0.7, 0.9, 1]},
#              scoring='neg_mean_squared_error')

# %%
# Do NOT Run This Cell
# Out:
# {'alpha': 0.01, 'l1_ratio': 0.9}
# ElasticNet(alpha=0.01, l1_ratio=0.9)

# %%
# Do NOT Run This Cell
# Out:
# MAE : 51376.41066292662
# MSE : 4923467432.616577
# RMSE: 70167.42429800724
# R² : 0.6399705781118845

# %% [markdown]
# #### **Question**
#
# - What combination of alpha and l1_ratio performed best?
# - Is the best model closer to Ridge or closer to LASSO?
